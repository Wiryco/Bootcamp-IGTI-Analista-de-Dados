# %% [markdown]
# <a href="https://colab.research.google.com/github/viniciusanl/Bootcamp-IGTI-Analista-de-Dados/blob/master/Trabalho_Pr%C3%A1tico_do_M%C3%B3dulo_1_Bootcamp_Analista_de_Dados_IGTI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# %% [markdown]
# # **INICIO**
#
# make_blobs(n_samples=500, centers=20, random_state=999)
#
# Ao executar o algoritmo K-Means, considere os parâmetros:
#
# init = k-means++
# max_iter = 300
# n_init = 10

# %%
x, y = make_blobs(n_samples=500, centers=20, random_state=999)

# %% [markdown]
# # **Primeira Pergunta**
#
# Considere o dataset gerado a partir das instruções do enunciado. Caso o algoritmo K-Means seja executado buscando apenas 1 cluster, qual será a coordenada do centroide ao final da execução?

# %%
kmeans = KMeans(n_clusters = 1, init = 'k-means++', max_iter=300, n_init=10)
pred_y = kmeans.fit_predict(x)
plt.scatter(x[:,0], x[:,1], c=pred_y)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 50, c = 'red')
plt.show()

# kmeans.cluster_centers_ verifica a cordenada do centroide
print("\n")
print("Cordenada -> ", kmeans.cluster_centers_);
# Out:
# Cordenada ->  [[ 0.02618523 -1.30384304]]

# %% [markdown]
# # **Segunda pergunta**
#
# Considere o dataset gerado a partir das instruções do enunciado. Caso o algoritmo seja executado buscando 5 clusters, qual será a soma dos quadrados intra-clusters (wcss) ao final da execução?

# %%
## Mesmo código da primeira questão. Alterar o n_clusters  para o informado no enunciado.
kmeans = KMeans(n_clusters = 5, init = 'k-means++', max_iter=300, n_init=10)
pred_y = kmeans.fit_predict(x)
plt.scatter(x[:,0], x[:,1], c=pred_y)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 50, c = 'red')
plt.show()

## Em seguida, o kmeans.inertia_ soma os quadrados wcss

print("\n");
print("Soma dos quadrados wcss - > ", kmeans.inertia_);
# Out:
# Soma dos quadrados wcss - >  4717.404091931214

# %% [markdown]
# # **Terceira perguta**
#
# Considere o dataset gerado a partir das instruções do enunciado. Caso o algoritmo seja executado buscando apenas 1 cluster, qual será a soma dos quadrados intra-clusters (wcss) ao final da execução?

# %%
## Mesmo código da primeira questão. Alterar o n_clusters  para o informado no enunciado.
kmeans = KMeans(n_clusters = 1, init = 'k-means++', max_iter=300, n_init=10)
pred_y = kmeans.fit_predict(x)
plt.scatter(x[:,0], x[:,1], c=pred_y)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 50, c = 'red')
plt.show()

## Em seguida, o kmeans.inertia_ soma os quadrados wcss

print("\n");
print("Soma dos quadrados wcss - > ", kmeans.inertia_);
# Out:
# Soma dos quadrados wcss - >  31547.372471390485

# %% [markdown]
# # **Quarta pergunta**
#
# Considerando o dataset gerado a partir das instruções do enunciado, qual das imagens representa o gráfico correto?

# %%
x, y = make_blobs(n_samples=500, centers=20, random_state=999)
plt.scatter(x[:,0], x[:,1])

# %% [markdown]
# # **Quinta pergunta**
#
# Considere o dataset gerado a partir das instruções do enunciado. Qual o número ideal de clusters?

# %%
## Esse é o dataset do enunciado, que vai gerar o grafico de Elbow
wcss = []
for i in range(1, 20):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 20), wcss)
plt.plot([1, 19],[wcss[0], wcss[len(wcss)-1]])
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.grid()
plt.show()

# %%
## Essa função calcula qual é o melhor cluster
## Confesso que, so de analisar esse código, eu nao entendi muito bem o que aconteceu
## Encontrei um link que me ajudou bastante a entender essa questão
## https://medium.com/pizzadedados/kmeans-e-metodo-do-cotovelo-94ded9fdf3a9
## Basicamente, o gráfico mostra que, apartir de um certo ponto, as variações são minimas


from math import *
def optimal_number_of_clusters(wcss):
    x1, y1 = 1, wcss[0]
    x2, y2 = 20, wcss[len(wcss)-1]

    distances = []
    for i in range(len(wcss)):
        x0 = i+2
        y0 = wcss[i]
        numerator = abs((y2-y1)*x0 - (x2-x1)*y0 + x2*y1 - y2*x1)
        denominator = sqrt((y2 - y1)**2 + (x2 - x1)**2)
        distances.append(numerator/denominator)
    
    return print("Número ótimo de clusters -> ", distances.index(max(distances)) + 2);

optimal_number_of_clusters(wcss)
# Out:
# Número ótimo de clusters ->  5

# %% [markdown]
# # **Sexta Pergunta**
#
# Qual o objetivo do algoritmo K-Means?
#
# Resposta: Clusterização

# %% [markdown]
# # **Sétima Pergunta**
#
# O algoritmo K-Means é baseado em qual tipo de aprendizagem?
#
# Resposta: Não supervisionada
